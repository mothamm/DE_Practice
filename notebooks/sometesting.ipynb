# %%
from sqlalchemy import *
from sqlalchemy.exc import SQLAlchemyError

class PostgresConnection:
    def __init__(self, username, password, host, port, db_name):
        conn_url = f'postgresql://{username}:{password}@{host}:{port}/{db_name}'
        self.engine = create_engine(conn_url)

    def execute_query(self, query, params=None, fetch=True):
        try:
            with self.engine.connect() as connection:
                result = connection.execute(text(query), params or {})

                if fetch and query.strip().lower().startswith("select"):
                    return result.fetchall()
                else:
                    connection.commit()
                    return None
        except SQLAlchemyErrro as e:
            print(f"Database Error as {e}")
            return None

    def close(self):
        self.engine.dispose()

# %%
demo = PostgresConnection(
    username = "admin", 
    password = "admin", 
    host = "postgres_db", 
    port = 5432, 
    db_name = "demo"
)
# Out:
# [('public', 'retail_db3', 'admin', None, False, False, False, False), ('pg_catalog', 'pg_statistic', 'admin', None, True, False, False, False), ('pg_catalog', 'pg_type', 'admin', None, True, False, False, False), ('pg_catalog', 'pg_foreign_table', 'admin', None, True, False, False, False), ('pg_catalog', 'pg_authid', 'admin', 'pg_global', True, False, False, False), ('pg_catalog', 'pg_statistic_ext_data', 'admin', None, True, False, False, False), ('pg_catalog', 'pg_user_mapping', 'admin', None, True, False, False, False), ('pg_catalog', 'pg_subscription', 'admin', 'pg_global', True, False, False, False), ('pg_catalog', 'pg_attribute', 'admin', None, True, False, False, False), ('pg_catalog', 'pg_proc', 'admin', None, True, False, False, False), ('pg_catalog', 'pg_class', 'admin', None, True, False, False, False), ('pg_catalog', 'pg_attrdef', 'admin', None, True, False, False, False), ('pg_catalog', 'pg_constraint', 'admin', None, True, False, False, False), ('pg_catalog', 'pg_inherits', 'admin', None, True, False, False, False), ('pg_catalog', 'pg_index', 'admin', None, True, False, False, False), ('pg_catalog', 'pg_operator', 'admin', None, True, False, False, False), ('pg_catalog', 'pg_opfamily', 'admin', None, True, False, False, False), ('pg_catalog', 'pg_opclass', 'admin', None, True, False, False, False), ('pg_catalog', 'pg_am', 'admin', None, True, False, False, False), ('pg_catalog', 'pg_amop', 'admin', None, True, False, False, False), ('pg_catalog', 'pg_amproc', 'admin', None, True, False, False, False), ('pg_catalog', 'pg_language', 'admin', None, True, False, False, False), ('pg_catalog', 'pg_largeobject_metadata', 'admin', None, True, False, False, False), ('pg_catalog', 'pg_aggregate', 'admin', None, True, False, False, False), ('pg_catalog', 'pg_statistic_ext', 'admin', None, True, False, False, False), ('pg_catalog', 'pg_rewrite', 'admin', None, True, False, False, False), ('pg_catalog', 'pg_trigger', 'admin', None, True, False, False, False), ('pg_catalog', 'pg_event_trigger', 'admin', None, True, False, False, False), ('pg_catalog', 'pg_description', 'admin', None, True, False, False, False), ('pg_catalog', 'pg_cast', 'admin', None, True, False, False, False), ('pg_catalog', 'pg_enum', 'admin', None, True, False, False, False), ('pg_catalog', 'pg_namespace', 'admin', None, True, False, False, False), ('pg_catalog', 'pg_conversion', 'admin', None, True, False, False, False), ('pg_catalog', 'pg_depend', 'admin', None, True, False, False, False), ('pg_catalog', 'pg_database', 'admin', 'pg_global', True, False, False, False), ('pg_catalog', 'pg_db_role_setting', 'admin', 'pg_global', True, False, False, False), ('pg_catalog', 'pg_tablespace', 'admin', 'pg_global', True, False, False, False), ('pg_catalog', 'pg_auth_members', 'admin', 'pg_global', True, False, False, False), ('pg_catalog', 'pg_shdepend', 'admin', 'pg_global', True, False, False, False), ('pg_catalog', 'pg_shdescription', 'admin', 'pg_global', True, False, False, False), ('pg_catalog', 'pg_ts_config', 'admin', None, True, False, False, False), ('pg_catalog', 'pg_ts_config_map', 'admin', None, True, False, False, False), ('pg_catalog', 'pg_ts_dict', 'admin', None, True, False, False, False), ('pg_catalog', 'pg_ts_parser', 'admin', None, True, False, False, False), ('pg_catalog', 'pg_ts_template', 'admin', None, True, False, False, False), ('pg_catalog', 'pg_extension', 'admin', None, True, False, False, False), ('pg_catalog', 'pg_foreign_data_wrapper', 'admin', None, True, False, False, False), ('pg_catalog', 'pg_foreign_server', 'admin', None, True, False, False, False), ('pg_catalog', 'pg_policy', 'admin', None, True, False, False, False), ('pg_catalog', 'pg_replication_origin', 'admin', 'pg_global', True, False, False, False), ('pg_catalog', 'pg_default_acl', 'admin', None, True, False, False, False), ('pg_catalog', 'pg_init_privs', 'admin', None, True, False, False, False), ('pg_catalog', 'pg_seclabel', 'admin', None, True, False, False, False) ...

# %%
demo.execute_query('CREATE TABLE retail_db2 (longitude FLOAT(53), latitude FLOAT(53))', fetch=False)

# %%
rows = demo.execute_query("SELECT * FROM retail_db2")
print(rows)
# Out:
# []
